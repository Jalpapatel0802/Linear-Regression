# %%
# Importing all libraries required.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings due to version problems
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\abc\Downloads\loan (1)\loan.csv")
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# # data description

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
# check duplicate rows
print(df.duplicated(subset=None,keep='first').count())
dup=df[df.duplicated(['id'])]
dup
# Out:
# 39717
# Empty DataFrame
# ...

# %%
# number of missing rows
print(df.isnull().all(axis=1).sum())
print(df.isnull().all(axis=0).sum())
# Out:
# 0
# 54

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
Null=round(df.isnull().sum()*100/len(df.index),2).sort_values(ascending=False)

# %%
Null.head(60)
# Out:
# verification_status_joint         100.00
# annual_inc_joint                  100.00
# mo_sin_old_rev_tl_op              100.00
# mo_sin_old_il_acct                100.00
# bc_util                           100.00
# bc_open_to_buy                    100.00
# avg_cur_bal                       100.00
# acc_open_past_24mths              100.00
# inq_last_12m                      100.00
# total_cu_tl                       100.00
# inq_fi                            100.00
# total_rev_hi_lim                  100.00
# all_util                          100.00
# max_bal_bc                        100.00
# open_rv_24m                       100.00
# open_rv_12m                       100.00
# il_util                           100.00
# total_bal_il                      100.00
# mths_since_rcnt_il                100.00
# open_il_24m                       100.00
# open_il_12m                       100.00
# open_il_6m                        100.00
# open_acc_6m                       100.00
# ...

# %%
#  drop columns having 100% missing values
df.drop(df.iloc[:,53:105],inplace=True,axis=1)

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %%
columns_drop_list1 = ["desc","mths_since_last_delinq","mths_since_last_record","next_pymnt_d","tot_hi_cred_lim"]
df.drop(labels = columns_drop_list1, axis =1, inplace=True)
columns_drop_list2 = ["mths_since_last_major_derog","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit"]
df.drop(labels = columns_drop_list2, axis =1, inplace=True)
columns_drop_list3 = ["member_id","url","emp_title","zip_code","tax_liens"]
df.drop(labels = columns_drop_list3, axis =1, inplace=True)

# %%
df.shape
# Out:
# (39717, 45)

# %%
df.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df['emp_length'].describe()
# Out:
# count         38642
# unique           11
# top       10+ years
# freq           8879
# Name: emp_length, dtype: object

# %%
df['emp_length'].fillna("0",inplace=True)

# %%
df['emp_length'].describe()

df['emp_length']=df.emp_length.str.extract('(\d+)')

# %%
df['emp_length']
# Out:
# 0        10
# 1         1
# 2        10
# 3        10
# 4         1
#          ..
# 39712     4
# 39713     3
# 39714     1
# 39715     1
# 39716     1
# Name: emp_length, Length: 39717, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df.pub_rec_bankruptcies.isnull().sum()
# Out:
# 697

# %%
df.pub_rec_bankruptcies.fillna("Nt known",inplace=True)

# %%
df.pub_rec_bankruptcies.isnull().sum()
# Out:
# 0

# %%
df['int_rate']=df['int_rate'].str.rstrip("%")

# %%
df['revol_util']=df['revol_util'].str.rstrip("%")

# %%
df['int_rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: object

# %%
df['revol_util']
# Out:
# 0        83.70
# 1         9.40
# 2        98.50
# 3           21
# 4        53.90
#          ...
# 39712    13.10
# 39713    26.90
# 39714    19.40
# 39715     0.70
# 39716    51.50
# Name: revol_util, Length: 39717, dtype: object

# %%
df.dtypes
# Out:
# id                              int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# loan_status                    object
# pymnt_plan                     object
# purpose                        object
# title                          object
# addr_state                     object
# dti                           float64
# delinq_2yrs                     int64
# earliest_cr_line               object
# inq_last_6mths                  int64
# open_acc                        int64
# pub_rec                         int64
# ...

# %%
df_cat=df.select_dtypes(include="object")

# %%
df_num=df.select_dtypes(exclude='object')

# %%
df_num.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
#        'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code'],
#       dtype='object')

# %%
df_cat.columns
# Out:
# Index(['term', 'int_rate', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'earliest_cr_line',
#        'revol_util', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'application_type', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df.issue_d=pd.to_datetime(df.issue_d,format="%b-%y")
df['year']=df['issue_d'].dt.year
df['month']=df['issue_d'].dt.month

# %%
df.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'year', 'month'],
#       dtype='object')

# %%
new = df['last_pymnt_d'].str.split("-", expand = True)

# %%
df.shape
# Out:
# (39717, 47)

# %%
new.rename(columns = {'0':'Month', '1':'date'}, inplace = True)

# %%
new.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df_final= pd.concat([df, new], axis=1, join="inner")

# %%
df_final.columns
# Out:
# Index([                        'id',                  'loan_amnt',
#                       'funded_amnt',            'funded_amnt_inv',
#                              'term',                   'int_rate',
#                       'installment',                      'grade',
#                         'sub_grade',                 'emp_length',
#                    'home_ownership',                 'annual_inc',
#               'verification_status',                    'issue_d',
#                       'loan_status',                 'pymnt_plan',
#                           'purpose',                      'title',
#                        'addr_state',                        'dti',
#                       'delinq_2yrs',           'earliest_cr_line',
#                    'inq_last_6mths',                   'open_acc',
#                           'pub_rec',                  'revol_bal',
#                        'revol_util',                  'total_acc',
# ...

# %%
df_final.drop('last_pymnt_d',axis=1)
# Out:
#             id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0      1077501       5000         5000           4975.0   36 months    10.65
# 1      1077430       2500         2500           2500.0   60 months    15.27
# 2      1077175       2400         2400           2400.0   36 months    15.96
# 3      1076863      10000        10000          10000.0   36 months    13.49
# 4      1075358       3000         3000           3000.0   60 months    12.69
# ...        ...        ...          ...              ...         ...      ...
# 39712    92187       2500         2500           1075.0   36 months     8.07
# 39713    90665       8500         8500            875.0   36 months    10.28
# 39714    90395       5000         5000           1325.0   36 months     8.07
# 39715    90376       5000         5000            650.0   36 months     7.43
# 39716    87023       7500         7500            800.0   36 months    13.75
#
# ...

# %%
df_final.rename(columns = {0:'last_pymnt_d_Month', 1:'last_pymnt_d_date'}, inplace = True)

# %%
df_final.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'year', 'month',
#        'last_pymnt_d_Month', 'last_pymnt_d_date'],
#       dtype='object')

# %%
df_final.drop(['last_pymnt_d_date','sub_grade'],axis=1,inplace=True)

# %%
df_final.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'year', 'month',
#        'last_pymnt_d_Month'],
#       dtype='object')

# %%
df_final.shape
# Out:
# (39717, 47)

# %%
df_final.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'year', 'month',
#        'last_pymnt_d_Month'],
#       dtype='object')

# %%
# how to calculate percentage of category in particular column

(df.loan_status.value_counts()*100/len(df))
# Out:
# Fully Paid     82.961956
# Charged Off    14.167737
# Current         2.870307
# Name: loan_status, dtype: float64

# %%
 df['annual_inc'].apply(pd.to_numeric)
# Out:
# 0         24000.0
# 1         30000.0
# 2         12252.0
# 3         49200.0
# 4         80000.0
#            ...
# 39712    110000.0
# 39713     18000.0
# 39714    100000.0
# 39715    200000.0
# 39716     22000.0
# Name: annual_inc, Length: 39717, dtype: float64

# %%
df["annual_inc"].describe()
# Out:
# count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# # Univarient Analysis

# %%
df=df[df["annual_inc"]<df["annual_inc"].quantile(0.99)]

# %%
df["annual_inc"].describe()
# Out:
# count     39319.000000
# mean      65524.215803
# std       35215.885297
# min        4000.000000
# 25%       40000.000000
# 50%       58000.000000
# 75%       81000.000000
# max      234996.000000
# Name: annual_inc, dtype: float64

# %%
sns.boxplot(df.annual_inc)
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_final.corr(),annot=True)
plt.show()

# %%
df_final.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'pub_rec_bankruptcies', 'year', 'month',
#        'last_pymnt_d_Month'],
#       dtype='object')

# %%
#final=['id','year','loan_amnt', 'funded_amnt', 'funded_amnt_inv','installment','total_pymnt', 'total_pymnt_inv',
       #'total_rec_prncp', 'total_rec_int', 'total_acc','open_acc','recoveries',
       #'collection_recovery_fee','last_pymnt_amnt','total_pymnt_inv',
      # 'total_rec_prncp', 'total_rec_int']
cla=['term', 'int_rate','grade', 'emp_length', 'home_ownership', 'annual_inc',
       'verification_status', 'issue_d','pymnt_plan',
       'purpose', 'title', 'addr_state', 'dti', 'delinq_2yrs',
       'earliest_cr_line', 'inq_last_6mths', 'pub_rec',
       'revol_bal', 'revol_util', 'total_rec_late_fee', 'last_pymnt_d','last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
       'application_type', 'pub_rec_bankruptcies','year', 'month',
       'last_pymnt_d_Month']

# %%
df_final.drop(cla,inplace=True,axis=1)

# %%
df_final.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
#        'loan_status', 'open_acc', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt'],
#       dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   loan_amnt                39717 non-null  int64
#  2   funded_amnt              39717 non-null  int64
#  3   funded_amnt_inv          39717 non-null  float64
#  4   installment              39717 non-null  float64
#  5   loan_status              39717 non-null  object
#  6   open_acc                 39717 non-null  int64
#  7   total_acc                39717 non-null  int64
#  8   initial_list_status      39717 non-null  object
#  9   out_prncp                39717 non-null  float64
#  10  out_prncp_inv            39717 non-null  float64
#  11  total_pymnt              39717 non-null  float64
#  12  total_pymnt_inv          39717 non-null  float64
#  13  total_rec_prncp          39717 non-null  float64
# ...

# %%
df_final_numerical=df_final.select_dtypes(include=[int,float])

# %%
df_final_numerical.shape
# Out:
# (39717, 16)

# %%
df_final_numerical.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
#        'open_acc', 'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt'],
#       dtype='object')

# %%
df_final_obj=df_final.select_dtypes(include="object")

# %%
df_final_obj.shape
# Out:
# (39717, 2)

# %%
df_final_obj.columns
# Out:
# Index(['loan_status', 'initial_list_status'], dtype='object')

# %%
var_1=['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment',
       'open_acc', 'total_acc']
var_2=['out_prncp_inv', 'total_pymnt',
       'total_pymnt_inv', 'total_rec_prncp']
var_3=['out_prncp' ,'total_rec_int', 'recoveries',
       'collection_recovery_fee', 'last_pymnt_amnt']

# %%
sns.pairplot(df_final_numerical, vars=var_1)
plt.show()

# %%
sns.pairplot(df_final_numerical, vars=var_2)
plt.show()

# %%
sns.pairplot(df_final_numerical, vars=var_3)
plt.show()

# %%
sns.countplot("loan_status",data=df_final_obj)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
sns.countplot( 'initial_list_status',data=df_final_obj)
# Out:
# <AxesSubplot:xlabel='initial_list_status', ylabel='count'>
