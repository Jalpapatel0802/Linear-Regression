# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

import seaborn as sns

# %%
# read and Understand data
bf = pd.read_csv(r"C:\Users\abc\Downloads\archive\Data-cleaning-for-beginners-using-pandas.csv")
bf.head()
#'feedback.csv'
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %% [markdown]
# # data preparation

# %%
bf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
bf.shape
# Out:
# (29, 7)

# %%
bf.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
null=pd.DataFrame(round((bf.isnull().sum()/len(bf.index))*100,2))

# %%
null
# Out:
#                  0
# Index         0.00
# Age          24.14
# Salary        0.00
# Rating        3.45
# Location      0.00
# Established   0.00
# Easy Apply    0.00

# %%
bf['Age']
# Out:
# 0     44.0
# 1     66.0
# 2      NaN
# 3     64.0
# 4     25.0
# 5     44.0
# 6     21.0
# 7     44.0
# 8     35.0
# 9     22.0
# 10    55.0
# 11    44.0
# 12     NaN
# 13    25.0
# 14    66.0
# 15    44.0
# 16    19.0
# 17     NaN
# 18    35.0
# 19    32.0
# 20     NaN
# 21    35.0
# 22    19.0
# 23     NaN
# 24    13.0
# 25    55.0
# 26     NaN
# 27    52.0
# 28     NaN
# Name: Age, dtype: float64

# %%
bf.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
bf
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
bf.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# dtype: bool

# %%
bf.select_dtypes(include='object').columns
# Out:
# Index(['Salary', 'Location', 'Easy Apply'], dtype='object')

# %%
bf.select_dtypes(include='int').columns
# Out:
# Index(['Index', 'Established'], dtype='object')

# %%
bf['Salary']=bf['Salary'].apply(lambda x:x.replace('k',''))

# %%
bf["Established"] = bf["Established"].replace(-1,np.nan)



bf["Established"].dropna()
# Out:
# 0     1999.0
# 1     2002.0
# 3     1988.0
# 4     2002.0
# 5     1999.0
# 10    2008.0
# 11    2009.0
# 12    1999.0
# 13    2019.0
# 14    2020.0
# 15    1999.0
# 16    1984.0
# 17    1943.0
# 18    1954.0
# 19    1955.0
# 20    1944.0
# 21    1946.0
# 22    1988.0
# 23    1999.0
# 24    1987.0
# 25    1980.0
# 26    1934.0
# 27    1935.0
# 28    1932.0
# Name: Established, dtype: float64

# %%
bf
# Out:
#     Index   Age    Salary  Rating       Location  Established Easy Apply  \
# 0       0  44.0   $44-$99     5.4       India,In       1999.0       TRUE
# 1       1  66.0   $55-$66     3.5    New York,Ny       2002.0       TRUE
# 2       2   NaN   $77-$89    -1.0    New York,Ny          NaN         -1
# 3       3  64.0   $44-$99     4.4       India In       1988.0         -1
# 4       4  25.0   $44-$99     6.4  Australia Aus       2002.0         -1
# 5       5  44.0   $77-$89     1.4       India,In       1999.0       TRUE
# 6       6  21.0   $44-$99     0.0    New York,Ny          NaN         -1
# 7       7  44.0   $44-$99    -1.0  Australia Aus          NaN         -1
# 8       8  35.0   $44-$99     5.4    New York,Ny          NaN         -1
# 9       9  22.0   $44-$99     7.7       India,In          NaN       TRUE
# 10     10  55.0   $10-$49     5.4       India,In       2008.0       TRUE
# 11     11  44.0   $10-$49     6.7       India,In       2009.0         -1
# ...

# %%
bf['Easy Apply']= bf['Easy Apply'].apply(lambda x:x.replace('-1','False'))

# %%
bf
# Out:
#     Index   Age    Salary  Rating       Location  Established Easy Apply  \
# 0       0  44.0   $44-$99     5.4       India,In       1999.0       TRUE
# 1       1  66.0   $55-$66     3.5    New York,Ny       2002.0       TRUE
# 2       2   NaN   $77-$89    -1.0    New York,Ny          NaN      False
# 3       3  64.0   $44-$99     4.4       India In       1988.0      False
# 4       4  25.0   $44-$99     6.4  Australia Aus       2002.0      False
# 5       5  44.0   $77-$89     1.4       India,In       1999.0       TRUE
# 6       6  21.0   $44-$99     0.0    New York,Ny          NaN      False
# 7       7  44.0   $44-$99    -1.0  Australia Aus          NaN      False
# 8       8  35.0   $44-$99     5.4    New York,Ny          NaN      False
# 9       9  22.0   $44-$99     7.7       India,In          NaN       TRUE
# 10     10  55.0   $10-$49     5.4       India,In       2008.0       TRUE
# 11     11  44.0   $10-$49     6.7       India,In       2009.0      False
# ...

# %%
sns.pairplot(bf,vars=['Index', 'Established'])
plt.show()

# %%
sns.heatmap(bf.corr(),annot=True)
plt.show()
